# %% [markdown]
# ### import libraries

# %%
import pandas as pd
import os

# %% [markdown]
# ### Base path to src folder

# %%
src_path = "../src"

# %% [markdown]
# ### file paths

# %%
leases_file = os.path.join(src_path,'leases.csv')
locations_file = os.path.join(src_path,'locations.csv')
properties_file = os.path.join(src_path,'properties.csv')
tenants_file = os.path.join(src_path,'tenants.csv')
units_file = os.path.join(src_path,'units.csv')

# %% [markdown]
# #### Read CSVs into Pandas Dataframes

# %%
leases = pd.read_csv(leases_file)
locations = pd.read_csv(locations_file)
properties = pd.read_csv(properties_file)
tenants = pd.read_csv(tenants_file)
units = pd.read_csv(units_file)

# %% [markdown]
# #### List of dataframes

# %%
dfs = [leases,locations,properties,tenants,units]
